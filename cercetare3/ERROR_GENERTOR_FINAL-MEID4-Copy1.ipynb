# %%
# !pip install datasets
# !pip install rowordnet
# !pip install phunspell

# %%
from bs4 import BeautifulSoup
import requests
from datasets import load_dataset
import random
import rowordnet
import pandas as pd
import numpy as np
import phunspell
import json
import datetime


# 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
from huggingface_hub import notebook_login

notebook_login()

# %%
wn = rowordnet.RoWordNet()
pspell = phunspell.Phunspell('ro_RO')

# %%
dataset = load_dataset("mateiaassAI/MEID4", streaming = True)
# Out:
# Resolving data files:   0%|          | 0/69 [00:00<?, ?it/s]

# %%
dictio_words = {1: {0: 0.0, 1: 0.3, 2: 1.01},
          3: {1: 0.0, 2: 0.3, 3: 1.01},
          6: {2: 0.0, 3: 0.1, 4: 0.75, 5: 1.01},
          9: {3: 0.0, 4: 0.2, 5: 0.5, 6: 0.7, 7: 1.01},
          16: {3: 0.0, 4: 0.1, 5: 0.3, 6: 0.4, 7: 0.8, 8: 1.01},
          20: {4: 0.0, 5: 0.1, 6: 0.3, 7: 0.5, 8: 0.8, 9: 1.01},
          30: {5: 0.0, 6: 0.1, 7: 0.3, 8: 0.5, 9: 0.8, 10: 1.01},
          100000000: None}

def number_of_words_changed(sentence_length):
  prob = random.randint(1, 100) / 100
  keys = list(dictio_words.keys())
  little_dict = {}
  for i in range(len(dictio_words) - 1):
      if sentence_length >= keys[i] and sentence_length < keys[i+1]:
          little_dict = dictio_words[keys[i]]
          values = list(little_dict.values())
          for j in range(len(values) - 1):
              if prob >= values[j] and prob < values[j+1]:
                  return list(little_dict.keys())[list(little_dict.values()).index(values[j])]

dictio_spell = {1: {0: 0.0, 1: 1.01},
          3: {1: 0.0, 2: 1.01},
          5: {1: 0.0, 2: 0.3, 3: 1.01},
          10: {1: 0.0, 2: 0.4, 3: 0.7, 4: 1.01},
          100000000: None}

def number_of_misspellings(word_length):
  prob = random.randint(1, 100) / 100

  keys = list(dictio_spell.keys())
  little_dict = {}
  for i in range(len(dictio_spell) - 1):
      if word_length >= keys[i] and word_length < keys[i+1]:
          little_dict = dictio_spell[keys[i]]
          values = list(little_dict.values())
          for j in range(len(values) - 1):
              if prob >= values[j] and prob < values[j+1]:
                  return list(little_dict.keys())[list(little_dict.values()).index(values[j])]

mispell_replacement_candidates = {
    'a': ['ea', 'ă', 'â', 'au', 'q', 'w', 's', 'z'],
    'ă': ['e', 'â', 'a', 'p', 'î', 'ț', 'ș'],
    'â': ['î', 'ă', 'a', 'ț'],
    'b': ['v', 'd', 'p', 'v', 'g', 'h', 'n'],
    'c': ['k', 'g', 'x', 'd', 'f', 'v'],
    'd': ['b', 'p', 'e', 'r', 's', 'f', 'x', 'c'],
    'e': ['ie', 'i', 'ă', 'ea', 'esc', 'w', 's', 'd', 'r'],
    'f': ['r', 'g', 'd', 'c', 'v'],
    'g': ['c', 't', 'h', 'f', 'v', 'b'],
    'h': ['y', 'g', 'j', 'b', 'n'],
    'i': ['ii', 'iii', 'e', 'î', 'y', 'ie', 'l', 'u', 'o', 'j', 'k'],
    'î': ['â', 'i', 'ă', 'ț'],
    'j': ['ș', 'u', 'h', 'k', 'n', 'm'],
    'k': ['c', 'i', 'j', 'l', 'm'],
    'l': ['n', 'i', 'o', 'p', 'k'],
    'm': ['n', 'j', 'k'],
    'n': ['m', 'l', 'j', 'h', 'b'],
    'o': ['u', 'or', 'i', 'k', 'l', 'p'],
    'p': ['q', 'b', 'd', 'o', 'l'],
    'q': ['c', 'p', 'w', 'a'],
    'r': ['e', 'd', 't', 'f'],
    's': ['ș', 'z', 'w', 'a', 'd', 's', 'z'],
    'ș': ['j', 's', 'ă', 'ț', 'p', 'l'],
    't': ['ț', 'r', 'f', 'g', 'y'],
    'ț': ['t', 'ă', 'â', 'ș', 'î'],
    'u': ['v', 'o', 'y', 'h', 'j', 'i'],
    'v': ['w', 'u', 'b', 'vr', 'c', 'f', 'g'],
    'w': ['v', 'q', 'e', 'a', 's'],
    'x': ['cs', 'gz', 'cș', 's', 'd', 'z', 'c'],
    'y': ['i', 't', 'u', 'g', 'h'],
    'z': ['s', 'a', 'x'],
}

diacritice_to_normal = {
    'ă': ['a', 'â', 'â', 'a'],
    'â' : ['a', 'ă', 'î', 'a'],
    'î' : ['i', 'i', 'i', 'i'],
    'ț' : ['t', 't', 't', 't'],
    'ș' : ['s', 's', 's', 's']
}

normal_to_diacritice = {
    'a' : ['ă', 'â', 'a', 'a'],
    'i' : ['î', 'î', 'i', 'i'],
    't' : ['ț', 'ț', 't', 't'],
    's' : ['ș', 'ș', 's', 's']
}

# %%
punctuation_dict = {
    ' ': {' ': 0.00, ',': 0.95, '.': 0.975, '-----': 1.01},
    ',': {' ': 0.00, ',': 0.41, '.': 0.95, '-----': 1.01},
    ';': {' ': 0.00, ',': 0.85, ';': 0.90, '-----': 1.01},
    ':': {' ': 0.00, ',': 0.90, ':': 0.92, '-----': 1.01},
    '-': {' ': 0.00, '-': 0.95, '-----': 1.01},
    '.': {' ': 0.00, ';': 0.20, '.': 0.23, '...': 0.97, '-----': 1.01},
    '?': {' ': 0.00, '.': 0.80, '?': 0.84, '!': 0.96, '-----': 1.01},
    '!': {' ': 0.00, '.': 0.80, '?': 0.90, '!': 0.97, '-----': 1.01},
    '...': {' ': 0.00, '...': 0.80, '-----': 1.01}
  }

def punctuation_substitution(letter):
  prob = random.randint(1, 100) / 100
  keys = list(punctuation_dict.keys())
  little_dict = punctuation_dict[letter]
  values = list(little_dict.values())
  for j in range(len(values) - 1):
    if prob >= values[j] and prob < values[j+1]:
      return list(little_dict.keys())[list(little_dict.values()).index(values[j])]

# %%
def copy_word(sentence, word, isSpace = True):
  if isSpace:
    sentence = sentence + " " + word
  else:
    sentence = sentence + word
  return sentence

def concatenate(sentence, word1, word2, isSpace = True):
  if isSpace:
    sentence = sentence + " " + word1 + word2
  else:
    sentence = sentence + word1 + word2
  return sentence

def transpose(sentence, word1, word2, isSpace = True):
  if isSpace:
    sentence = sentence + " " + word2 + " " + word1
  else:
    sentence = sentence + word2 + " " + word1
  return sentence

# %%
def noisy_diacritice(letter):
    if letter in diacritice_to_normal.keys():
        r_nr = random.randint(0, 3)
        # print(letter, diacritice_to_normal[letter][r_nr])
        return diacritice_to_normal[letter][r_nr]
    elif letter in normal_to_diacritice.keys():
        r_nr = random.randint(0, 3)
        return normal_to_diacritice[letter][r_nr]
        # print(letter, normal_to_diacritice[letter][r_nr])
    return letter

def copy_letter(word, letter):
    if letter is None:
        letter = ''
    return word + noisy_diacritice(letter)
    
def transpose_letters(word, letter1, letter2):
    if letter2 is None:
        letter2 = ''
    return word + noisy_diacritice(letter2) + letter1

def replace_letter(word, letter):
    if letter is None:
        letter = ''
    return word + noisy_diacritice(letter)
    
def insert_letter(word, letter, new_letter):
    if letter is None:
        letter = ''
    return word + noisy_diacritice(letter) + new_letter

# %%
alphabet = "аăâbcdefghiîjklmnopqrsștțuvwxyz"
alphabet2 = "аăâbcdefghiîjklmnopqrsștțuvwxyz----"
noisy_letter = "-._&@(){}`\';--,\":"

def misspell(word):
  number_of_changed_letters = number_of_misspellings(len(word))
  letters_to_be_changed = np.random.choice(np.arange(0, len(word)), size=number_of_changed_letters, replace=False).tolist()
  wrong_word = ""
  skip_flag = False
  for i in range(len(word)):
    if skip_flag == True:
      skip_flag = False
      continue
    letter = word[i]

    # Letter not to be changed
    if i not in letters_to_be_changed:
      wrong_word = copy_letter(wrong_word, letter)
      continue

    # Type of misspelling - Distribution of Probability
    letter_error_action = random.randint(1, 100) / 100

    # DELETION
    if letter_error_action <= 0.25:
      continue

    # INSERTION
    if letter_error_action > 0.25 and letter_error_action <= 0.45:
      alphabet_letter = alphabet2[random.randint(0, len(alphabet2) - 1)]
      wrong_word = insert_letter(wrong_word, letter, alphabet_letter)          
      continue

    if letter_error_action % 0.2 > 0.12:
        wrong_word = copy_letter(wrong_word, noisy_letter[random.randint(0, len(noisy_letter) -1)])          

    # TRANSPOSITION
    if letter_error_action > 0.35 and letter_error_action <= 0.65 and i < len(word) - 1:
      next_letter = word[i + 1]
      wrong_word = transpose_letters(wrong_word, letter, next_letter)
      skip_flag = True
      continue

    # REPLACEMENT
    if letter_error_action > 0.60:
      if letter.lower() not in alphabet:
        alphabet_letter = letter
      else:
        # if letter_error_action <= 0.68 and i == 0:
        #   alphabet_letter = letter.lower() if letter.islower() else letter.upper()

        if letter_error_action <= 0.7 and i == len(word) - 1 and letter.lower() in ['a', 'i', 'l']:
          continue

        if letter_error_action > 0.90:
          alphabet_letter = alphabet[random.randint(0, len(alphabet) - 1)]
        else:
            try:
                alphabet_letter = random.choice(mispell_replacement_candidates[letter.lower()])
            except KeyError:
                alphabet_letter = letter

      wrong_word = replace_letter(wrong_word, alphabet_letter)
      continue

    # DEFAULT
    wrong_word = copy_letter(wrong_word, letter)

  return wrong_word

# %%
def morphologic_dex(word):
  if len(word) <= 3:
    return word

  url = f'https://dexonline.ro/definitie/{word}/paradigma'
  response = requests.get(url)
  try :
      if response.status_code == 200:
        action = random.randint(1, 100) / 100
        soup = BeautifulSoup(response.text, 'html.parser')
        if action < 0.7:
            para_lexemes = soup.find_all('div', class_='paraLexeme')
        
            for para_lexeme in para_lexemes:
              lexeme_name = para_lexeme.find('span', class_='lexemeName').text
              if lexeme_name == word:
                table = para_lexeme.find('table', class_='lexeme')
        
                if table:
                  unique_cells = set()
                  form_cells = table.find_all('td', class_='form')
        
                  for cell in form_cells:
                    if not cell.find(class_='elisionHidden') and not cell.find(class_='notRecommendedHidden'):
                      text = cell.get_text(strip=True)
                      if '—' not in text:
                        text = text.replace(')', ' ').replace('(', '')
                        unique_cells.add(text)
        
                  if unique_cells:
                    random_word = random.choice(list(unique_cells))
                    return random_word
                    # return unique_cells
        else:
            spans_synonyms = soup.find_all('span', class_='badge-relation badge-relation-1')
            unique_cells = set()
    
            for spans in spans_synonyms:
                text = spans.text.replace('\'', ' ').replace(' ', '')
                unique_cells.add(text)
    
            if unique_cells:
                return random.choice(list(unique_cells))
            # return unique_cells
      return word
  except Exception as e:
      return word

# %%
lista_conjunctii = ['și', 'dar', 'iar', 'că', 'să', 'ci', 'fie', 'sau', 'ori', 'ci și', 'ca să', 'încât să', 'nici', 'însă', 'ba', 'deci', 'așadar', 'totuși', 'însăși', 'chiar', 'tot', 'încă', 'atât', 'pe când', 'în timp ce',
                    'cu toate că', 'întrucât', 'precum', 'totodată', 'care', 'pe care']

lista_prepozitii = ['la', 'în', 'către', 'contrar', 'fără', 'după', 'cu', 'lângă', 'asupra', 'de', 'de la', 'despre', 'dimprejurul', 'din', 'dinaintea', 'înspre', 'între', 'înăuntrul', 'împotriva', 'împrejurul', 'înaintea',
                    'înapoia', 'întru', 'dedesubtul', 'datorită', 'printre', 'prin', 'primprejur', 'peste', 'pentru', 'pe', 'până', 'via', 'spre', 'sub', 'din cauza', 'din pricina', 'în vederea', 'cu excepția', 'cu tot cu', 'a']

lista_articole_posesive = ['a', 'ai', 'ale', 'al', 'alor', 'a', 'ai', 'ale', 'al', 'alor', 'a', 'ai', 'ale', 'al', 'alor', 'a', 'ai', 'ale', 'al', 'alor', 'a', 'ai', 'ale', 'al', 'alor', 'a', 'ai', 'ale', 'al', 'alor']
lista_articole_demonstrative = ['cel', 'cea', 'cei', 'cele', 'celui', 'celei', 'celor', 'cel', 'cea', 'cei', 'cele', 'celui', 'celei', 'celor', 'cel', 'cea', 'cei', 'cele', 'celui', 'celei', 'celor', 'cel', 'cea', 'cei', 'cele', 'celui', 'celei', 'celor']
lista_articole_nehotarate = ['un', 'o', 'niste', 'unor', 'unui', 'unei', 'un', 'o', 'niste', 'unor', 'unui', 'unei', 'un', 'o', 'niste', 'unor', 'unui', 'unei','un', 'o', 'niste', 'unor', 'unui', 'unei']

def substitute(word_metadata):
  action = random.randint(1, 100) / 100

  if len(word_metadata.text) > 8 and action > 0.6:
    action = 0.5

  # RoWORDNET
  if action <= 0.2:
    word = word_metadata.lemma_.lower()
    syn_list = []
    synset_ids = wn.synsets(literal=word)
    for s in synset_ids:
      if word in wn.synset(s).literals:
        for literal in wn.synset(s).literals:
          if literal != word and literal not in syn_list:
            syn_list.append(literal)
    if len(syn_list) > 0:
      return random.choice(syn_list)
    else:
      return word_metadata.text

  # DEXONLINE
  elif action > 0.2 and action <= 0.7:

    if word_metadata.pos_ == 'CCONJ' and action <= 0.3:
      return random.choice(lista_conjunctii)

    if word_metadata.pos_ == 'ADP' and action <= 0.3:
      return random.choice(lista_prepozitii)

    if word_metadata.pos_ == 'DET' and word_metadata.text in lista_articole_posesive and action <= 0.3:
      return random.choice(lista_articole_posesive)
    if word_metadata.pos_ == 'DET' and word_metadata.text in lista_articole_demonstrative and action <= 0.3:
      return random.choice(lista_articole_demonstrative)

    if word_metadata.pos_ == 'DET' and word_metadata.text in lista_articole_nehotarate and action <= 0.3:
      return random.choice(lista_articole_nehotarate)
    return morphologic_dex(word_metadata.lemma_)

  # SPELLCHECKER
  elif action > 0.7:
    sugestions = list(pspell.suggest(word_metadata.text))
    if len(sugestions) == 0:
      return morphologic_dex(word_metadata.lemma_)
    return random.choice(sugestions)

  return word_metadata.text

# %%
def save_data(data, counter):
  output_file = f'MEID5/{counter}.jsonl'
  with open(output_file, "w", encoding="utf-8") as json_file:
    for example_parsed in data:
      json.dump(example_parsed, json_file, ensure_ascii=False)#, indent=4)
      json_file.write('\n')

# %%
iterator = iter(dataset["train"])
for example in iterator:
    print(example)
    break
# dataset["train"][0]["wrong"]
# Out:
# {'wrong': 'HOTĂRÂREA Nr. 8 din 18 ianuarie 2011', 'right': 'DECIZIE nr. 8 din 18 ianuarie 2011'}

# %%
import spacy
iterator = iter(dataset["train"])
count = 0
data = []
nlp_cuv = spacy.load("ro_core_news_sm")

punctuation_list = [' ', ',', ';', ':', '-', '.', '?', '!', '...']

contor_file = 14
breakline = 10000
deadline = 300000
after_limit = 240000

for example in iterator:
    count += 1
    if count <= after_limit:
        if count % breakline == 0:
            print(count)
        continue

    if count % 100 == 0:
        print(count, datetime.datetime.now())
    
    correct_sentence = example['wrong']
    doc = nlp_cuv(correct_sentence)
    list_of_words = [token for token in doc if not token.is_punct]
    list_of_words_lemma = [token.lemma_ for token in doc if not token.is_punct]

    word_count = len(list_of_words)

    # list_of_words = [word['FORM'] for word in metadata if word['FEATS'] != '_']
    if len(list_of_words) < 3:
        continue
        
    nr_errs = number_of_words_changed(word_count)
    numbers_to_be_changed = np.random.choice(np.arange(0, word_count), size=nr_errs, replace=False).tolist()

    skip_flag = False
    wrong_sentence = ""
    nr_word = -1
    for i in range(len(list_of_words)):
      if skip_flag == True:
        skip_flag = False
        nr_word += 1
        continue

      word = list_of_words[i]
      word_lemma = list_of_words_lemma[i]  
        
      if word in punctuation_list:
        new_punctuation = punctuation_substitution(word.text)
        if new_punctuation in ['-', ' ']:
          wrong_sentence = copy_word(wrong_sentence, new_punctuation, False)
        else:
          wrong_sentence = copy_word(wrong_sentence, word.text)

        continue

      nr_word += 1

      # Token not to be changed
      if nr_word not in numbers_to_be_changed:
        wrong_sentence = copy_word(wrong_sentence, word.text)
        continue

      # Type of error - Distribution of Probability
      token_error_action = random.randint(1, 100) / 100

      # CONCATENATION
      if token_error_action <= 0.10 and i < len(list_of_words) - 1:
        next_word = list_of_words[i + 1]
        if str(next_word.morph) != '':
          wrong_sentence = concatenate(wrong_sentence, word.text, next_word.text)
          skip_flag = True
          continue

      # TRANSPOSITION
      if token_error_action > 0.12 and token_error_action <= 0.2 and i < len(list_of_words) - 1:
        next_word = list_of_words[i + 1]
        if str(next_word.morph) != '':
          wrong_sentence = transpose(wrong_sentence, word.text, next_word.text)
          skip_flag = True
          continue

      # DELETION
      if token_error_action > 0.2 and token_error_action <= 0.25:
        continue

      # MISSPELLING
      if token_error_action > 0.25 and token_error_action <= 0.6:
        wrong_sentence = copy_word(wrong_sentence, misspell(word.text))
# 298000 2024-09-23 20:29:43.491246
# 298100 2024-09-23 20:30:22.238329
# 298200 2024-09-23 20:31:11.976383
# 298300 2024-09-23 20:31:47.932970
# 298400 2024-09-23 20:32:36.062357
# 298500 2024-09-23 20:33:26.559188
# 298600 2024-09-23 20:34:12.740890
# 298700 2024-09-23 20:35:08.785814
# 298800 2024-09-23 20:36:02.559282
# 298900 2024-09-23 20:36:46.529624
# 299000 2024-09-23 20:37:20.854329
# 299100 2024-09-23 20:37:53.119149
# 299200 2024-09-23 20:38:27.437945
# 299300 2024-09-23 20:39:14.562961
# 299400 2024-09-23 20:40:01.435633
# 299500 2024-09-23 20:41:01.331301
# 299600 2024-09-23 20:41:50.804948
# 299700 2024-09-23 20:42:41.710957
# 299800 2024-09-23 20:43:33.022192
# 299900 2024-09-23 20:44:14.523899
# 300000 2024-09-23 20:45:13.839569
# 300000 2024-09-23 20:45:13.846502 20

# %%
if count % breakline == 0:
      contor_file += 1
      print(count, datetime.datetime.now(), contor_file)
      save_data(data, contor_file)
      data = []

# %%
# !python -m spacy download ro_core_news_sm
# Out:
# Collecting ro-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ro_core_news_sm-3.7.0/ro_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.9 MB 330.3 kB/s eta 0:00:39
#      --------------------------------------- 0.1/12.9 MB 544.7 kB/s eta 0:00:24
#       --------------------------------------- 0.2/12.9 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.6/12.9 MB 3.0 MB/s eta 0:00:05
#      -- ------------------------------------- 0.7/12.9 MB 3.2 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.5/12.9 MB 5.6 MB/s eta 0:00:03
#      ------ --------------------------------- 2.1/12.9 MB 6.4 MB/s eta 0:00:02
#      ------- -------------------------------- 2.6/12.9 MB 6.8 MB/s eta 0:00:02
#      --------- ------------------------------ 3.0/12.9 MB 7.1 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.5/12.9 MB 7.4 MB/s eta 0:00:02
#      ------------ --------------------------- 3.9/12.9 MB 7.6 MB/s eta 0:00:02
#      ------------- -------------------------- 4.4/12.9 MB 7.8 MB/s eta 0:00:02
#      --------------- ------------------------ 4.9/12.9 MB 8.0 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.4/12.9 MB 8.1 MB/s eta 0:00:01
#      ------------------ --------------------- 5.8/12.9 MB 8.5 MB/s eta 0:00:01
#      ------------------- -------------------- 6.3/12.9 MB 8.6 MB/s eta 0:00:01
#      --------------------- ------------------ 6.8/12.9 MB 8.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.2/12.9 MB 8.7 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.7/12.9 MB 8.8 MB/s eta 0:00:01
#      ------------------------- -------------- 8.2/12.9 MB 8.9 MB/s eta 0:00:01
#      -------------------------- ------------- 8.6/12.9 MB 8.9 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.9 MB 8.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.5/12.9 MB 8.9 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.9 MB 8.8 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.9 MB 8.8 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.9 MB 9.8 MB/s eta 0:00:01
#      -------------------------------- ------ 10.9/12.9 MB 10.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.2/12.9 MB 9.9 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.6/12.9 MB 9.6 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.9 MB 9.6 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.9 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.9 MB 9.2 MB/s eta 0:00:01
#      ---------------------------------------  12.9/12.9 MB 9.2 MB/s eta 0:00:01
#      ---------------------------------------- 12.9/12.9 MB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from ro-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vmatei\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->ro-core-news-sm==3.7.0) (2.1.5)
# Installing collected packages: ro-core-news-sm
# Successfully installed ro-core-news-sm-3.7.0
# [+] Download and installation successful
# You can now load the package via spacy.load('ro_core_news_sm')
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
