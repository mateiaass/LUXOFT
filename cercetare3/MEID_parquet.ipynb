# %%
import os
import pandas as pd
from io import StringIO
import pyarrow as pa
import pyarrow.parquet as pq

def jsonl_files_to_dataframe(directory_path):
    data = []
    i = 0;
    j = 0;
    for file_name in os.listdir(directory_path):
        jsonl_file_path = os.path.join(directory_path, file_name)
        with open(jsonl_file_path, 'r', encoding='utf-8') as f:
            for line in f:
                data.append(pd.read_json(StringIO(line), lines=True))
        i += 1
        if i == 10:
            j += 1
            print(j, "HAHA")
            df = pd.concat(data, ignore_index=True)
            table = pa.Table.from_pandas(df);
            pq.write_table(table, f'./MEID_P/{j}.parquet')
            data = []
            i = 0
    
    return df

directory_path = './MEID/'
jsonl_files_to_dataframe(directory_path)
# Out:
# 1 HAHA
# 2 HAHA
# 3 HAHA
# 4 HAHA
# 5 HAHA
# 6 HAHA
# 7 HAHA
#                                                    wrong  \
# 0      Po_iulât,la a fostă estimată la 5.000 de exemp...
# 1      Nagy et al.  2005  au studiat peșterile din ve...
# 2      Nu sunt oară anțe-rîoar-e relativ mărimea la p...
# 3      populațiilor actual a fostestimată pe baza ind...
# 4      Indicele de densitate  indice densitate liliec...
# ...                                                  ...
# 46736                    ORDINnr. 4.459 din 4 iunie 2020
# 46737  pentru determinare Ordinului ministrului educa...
# 46738      Monitorul OFICIAL nr. 514 din 16 cireșar 2020
# 46739  vAad in vedere prevederile art. 24 alin. ( 3 )...
# 46740  ținând cont de dispozițiile Hotărârii Guvernul...
#
#                                                    right
# 0      Populația României a fost estimată la 5.000 de...
# 1      Nagy et al., 2005, au studiat peșterile din ve...
# 2      Nu sunt date anterioare privitoare la mărimea ...
# 3      Populația actuală a fost estimată pe baza indi...
# 4      Indicele de densitate: indice densitate liliec...
# ...                                                  ...
# 46736                   ORDIN nr. 4.459 din 4 iunie 2020
# 46737  pentru modificarea Ordinului ministrului educa...
# 46738        MONITORUL OFICIAL nr. 514 din 16 iunie 2020
# 46739  Având în vedere prevederile art. 24 alin. (3) ...
# 46740  ținând cont de dispozițiile Hotărârii Guvernul...
#
# [46741 rows x 2 columns]
